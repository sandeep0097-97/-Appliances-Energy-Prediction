# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep0097-97/-Appliances-Energy-Prediction/blob/main/Appliances_Energy_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data-driven prediction of energy use of appliances**
#
# **The data set is at 10 min for about 4.5 months. The house temperature and humidity conditions were monitored with a ZigBee wireless sensor network. Each wireless node transmitted the temperature and humidity conditions around 3.3 min. Then, the wireless data was averaged for 10 minutes periods. The energy data was logged every 10 minutes with m-bus energy meters. Weather from the nearest airport weather station Chievres Airport, Belgium) was downloaded from a public data set from Reliable Prognosis (rp5.ru) and merged together with the experimental data sets using the date and time column. Two random variables have been included in the data set for testing the regression models and to filter out non-predictive attributes (parameters).**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
from sklearn.decomposition import PCA, LatentDirichletAllocation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
from sklearn import neighbors
from sklearn.svm import SVR
import time
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from tensorflow.keras import Sequential, layers, Input

# %%
warnings.filterwarnings('ignore')

# %%
file_path = '/content/data_application_energy.csv'
df = pd.read_csv(file_path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
#  18  RH_8         19735 non-null  float64
#  19  T9           19735 non-null  float64
#  20  RH_9         19735 non-null  float64
#  21  T_out        19735 non-null  float64
#  22  Press_mm_hg  19735 non-null  float64
#  23  RH_out       19735 non-null  float64
#  24  Windspeed    19735 non-null  float64
#  25  Visibility   19735 non-null  float64
#  26  Tdewpoint    19735 non-null  float64
#  27  rv1          19735 non-null  float64
#  28  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %% [markdown]
# **Number of entries : 19735 <br> No of features : 27 ( 2 Random Variables included )<br> Target Variable : Appliances <br> All features are numerical. No categorical variables. There seems to be no null values in our data set.**

# %%
df.head()
# Out:
#                   date  Appliances  lights  ...  Tdewpoint        rv1        rv2
# 0  2016-01-11 17:00:00          60      30  ...        5.3  13.275433  13.275433
# 1  2016-01-11 17:10:00          60      30  ...        5.2  18.606195  18.606195
# 2  2016-01-11 17:20:00          50      30  ...        5.1  28.642668  28.642668
# 3  2016-01-11 17:30:00          50      40  ...        5.0  45.410389  45.410389
# 4  2016-01-11 17:40:00          60      40  ...        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
df.describe()
# Out:
#          Appliances        lights  ...           rv1           rv2
# count  19735.000000  19735.000000  ...  19735.000000  19735.000000
# mean      97.694958      3.801875  ...     24.988033     24.988033
# std      102.524891      7.935988  ...     14.496634     14.496634
# min       10.000000      0.000000  ...      0.005322      0.005322
# 25%       50.000000      0.000000  ...     12.497889     12.497889
# 50%       60.000000      0.000000  ...     24.897653     24.897653
# 75%      100.000000      0.000000  ...     37.583769     37.583769
# max     1080.000000     70.000000  ...     49.996530     49.996530
#
# [8 rows x 28 columns]

# %%
temp_dict = {
    'T1' : 'temp_kitchen', 'T2' : 'temp_living', 'T3' : 'temp_laundry', 
    'T4' : 'temp_office', 'T5' : 'temp_bath', 'T6' : 'temp_outside',
    'T7' : 'temp_iron', 'T8' : 'temp_teen', 'T9' : 'temp_parents', 'T_out' : 'temp_station'
}

# %%
energy_df = df.rename(columns=temp_dict)

# %%
humid_dict = {
    'RH_1' : 'humid_kitchen', 'RH_2' : 'humid_living', 'RH_3' : 'humid_laundry', 
    'RH_4' : 'humid_office', 'RH_5' : 'humid_bath', 'RH_6' : 'humid_outside',
    'RH_7' : 'humid_iron', 'RH_8' : 'humid_teen', 'RH_9' : 'humid_parents', 'RH_out' : 'humid_station'
}

# %%
energy_df = energy_df.rename(columns=humid_dict)

# %%
energy_df[temp_dict.values()].describe()
# Out:
#        temp_kitchen   temp_living  ...  temp_parents  temp_station
# count  19735.000000  19735.000000  ...  19735.000000  19735.000000
# mean      21.686571     20.341219  ...     19.485828      7.411665
# std        1.606066      2.192974  ...      2.014712      5.317409
# min       16.790000     16.100000  ...     14.890000     -5.000000
# 25%       20.760000     18.790000  ...     18.000000      3.666667
# 50%       21.600000     20.000000  ...     19.390000      6.916667
# 75%       22.600000     21.500000  ...     20.600000     10.408333
# max       26.260000     29.856667  ...     24.500000     26.100000
#
# [8 rows x 10 columns]

# %% [markdown]
# **OBSERVATIONS** : <br>
# 1. **Average outside temperature over a period of 4.5 months is around 7.5 degrees. It ranges from -6 - 28 degrees**
# 2. **While average temperature inside the building has been around 20 degrees for all the rooms. It ranges from 14 - 30 degrees**
# 3. **Which implies, Warming appliances have been used to keep the insides of the building warm. There must be some sort of direct correlation between temperature and consumption of energy inside house.**

# %%
energy_df[humid_dict.values()].describe()
# Out:
#        humid_kitchen  humid_living  ...  humid_parents  humid_station
# count   19735.000000  19735.000000  ...   19735.000000   19735.000000
# mean       40.259739     40.420420  ...      41.552401      79.750418
# std         3.979299      4.069813  ...       4.151497      14.901088
# min        27.023333     20.463333  ...      29.166667      24.000000
# 25%        37.333333     37.900000  ...      38.500000      70.333333
# 50%        39.656667     40.500000  ...      40.900000      83.666667
# 75%        43.066667     43.260000  ...      44.338095      91.666667
# max        63.360000     56.026667  ...      53.326667     100.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# **OBSERVATIONS :**
# 1. **Average humidity outside the building has been higher than the average humidity inside.**
# 2. **Average humidity at the weather station is significantly higher compared to outside humidity near the building.**
# 3. **Average humidity in the bathroom is significantly higher compared to other rooms due to obvious reasons.**
# 4. **Kids and parent room show a comparatively higher average humidity as well signifying the fact that, inhabitants of this building spend most of their time in these buildings.**

# %%
weather_cols = list(set(energy_df.columns) - set(list(temp_dict.values())) - set(list(humid_dict.values())) - {'Appliances', 'lights', 'rv1', 'rv2'})
weather_cols
# Out:
# ['date', 'Windspeed', 'Tdewpoint', 'Press_mm_hg', 'Visibility']

# %% [markdown]
# **Distribution of our appliances energy usage :**

# %%
df.Appliances.describe()
# Out:
# count    19735.000000
# mean        97.694958
# std        102.524891
# min         10.000000
# 25%         50.000000
# 50%         60.000000
# 75%        100.000000
# max       1080.000000
# Name: Appliances, dtype: float64

# %%
sns.histplot(df['Appliances'],bins=50)

# %% [markdown]
# **75% of Appliance consumption is less than 100 Wh . With the maximum consumption of 1080 Wh , there will be outliers in this column and there are small number of cases where consumption is very high**

# %%
df.lights.hist(bins=10)

# %%
df.lights.value_counts()
# Out:
# 0     15252
# 10     2212
# 20     1624
# 30      559
# 40       77
# 50        9
# 70        1
# 60        1
# Name: lights, dtype: int64

# %% [markdown]
# **Since most of the value in lights column is 0, it wont be playing much role in our model. Hence we drop the lights feature from our dataframe.**

# %%
energy_df = energy_df.drop('lights', axis=1)

# %% [markdown]
# ### **Energy consumption**

# %% [markdown]
# **Energy Consumption pattern of the household at different times of the day over different time periods**

# %%
energy_df['weekday'] = ((pd.to_datetime(energy_df['date']).dt.dayofweek)// 5 == 0).astype(int)
energy_df['hour'] = pd.to_datetime(energy_df['date']).dt.hour
energy_df['month'] = pd.to_datetime(energy_df['date']).dt.month

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
energy_df.groupby('hour').agg({'Appliances' : 'mean'}).plot.bar(ax=ax)
ax.set_ylabel('Appliance energy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance energy (Wh)')

# %% [markdown]
# **Above figure is a representation of average energy consumption of appliances at different time of the day over a period of 4.5 months. We observe two peak hours. One at 11 am in the morning and other at 6 PM in the evening. While the peak at 11 am is shallow and low, peak at 6 PM is comparatively higher and sharper.**
#
# **We observe that over the sleeping hours (10 PM - 6 AM) the energy consumption of appliances is around 50 Wh. After about 6 AM, energy consumption starts to rise gradually up until 11 AM (probably due to morning chores). And then gradually decreases to around 100 Wh at about 3 PM. After which the energy consumption drastically shoots up up until 6 PM in the evening (probably due to requirement lights in rooms). However energy consumption of appliances reverts back to 50 Wh, as night approaches and people in the house go to bed at around 10 PM.**

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'Appliances' : 'mean'}).plot.bar(ax=ax)
ax.set_ylabel('Appliance enrergy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance enrergy (Wh)')

# %% [markdown]
# **A trend of high consumption hours for each month seems to be similar to the over all trend**

# %% [markdown]
# **What about weekdays and weekends?**

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
week_df = energy_df.groupby(['weekday','hour']).agg({'Appliances':'mean'}).reset_index(0)
week_df[week_df.weekday==0].Appliances.plot.bar(ax=ax[0], label='weekends')
week_df[week_df.weekday==1].Appliances.plot.bar(ax=ax[1], label='weekdays')
ax[0].legend(loc='best')
ax[1].legend(loc='best')
ax[0].set_ylabel('Appliance Energy (Wh)')
ax[1].set_ylabel('Appliance Energy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance Energy (Wh)')

# %% [markdown]
# **We observe that the energy consumption of appliances during the office hours (8 AM - 4 PM) is higher in weekends compared to the weekdays. Also, average overall consumption is higher in weekends is pretty high.**

# %% [markdown]
# **Lets look at how temperature and humidity levels vary inside different rooms !**

# %% [markdown]
# ### **Temperature levels**

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, temp in enumerate(temp_dict.values()):
  energy_df.groupby('hour').agg({temp : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(temp)

# %% [markdown]
# **The average temperature inside each of the rooms has been almost constant over the day. However the average temperature outside the building and near the station changes over the course of the day. The average night time temperature is around 6 degree C, while average day time temperature varies over hours and peaks to 12 degree C at about 2-3 PM in the afternoon.**

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'temp_outside' : 'mean'}).plot.bar(ax=ax)

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, temp in enumerate(temp_dict.values()):
  energy_df.groupby('month').agg({temp : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(temp)

# %% [markdown]
# **We observe a significant increasing trend of daytime outside temperatures over the course of 5 months starting from an avg of 4 degree celsius in 1st month to an average of 15 degree celsius in month 5. The outside temperatures seem to have an impact over temperature inside too, although the variance of temperatures inside the building is low, since the temperature inside is controlled. Although the increase temperature seem to have no impact on the appliance consumtion patterns.**

# %% [markdown]
# ### **Humidity levels**

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, humid in enumerate(humid_dict.values()):
  energy_df.groupby('hour').agg({humid : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(humid)

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'humid_outside' : 'mean'}).plot.bar(ax=ax)

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, humid in enumerate(humid_dict.values()):
  energy_df.groupby('month').agg({humid : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(humid)

# %% [markdown]
# **Although the humidity outside building tend to decrease over months, the humidity inside rooms seem to be unaffected. The humidity levels outside seem to be negatively correlated to with the temperature levels outside. Lets check !**

# %%
energy_df[['temp_outside', 'humid_outside']].corr()
# Out:
#                temp_outside  humid_outside
# temp_outside       1.000000      -0.672137
# humid_outside     -0.672137       1.000000

# %% [markdown]
# **Indeed there is a strong negative correlation between temperature and humidity levels outside. As temperature increases, moisture levels in the air decreases. We also observe that during the day time when the temperatures are high, humidity levels are low.**

# %% [markdown]
# **Lets look at correlation matrix of temperature and humidity levels**

# %%
cols = list(temp_dict.values())
cols.extend(list(humid_dict.values()))
cols.extend(['Appliances'])
fig, ax = plt.subplots(1,1,figsize=(15,15))
sns.heatmap(energy_df[cols].corr(), ax=ax, annot=True)

# %% [markdown]
# **OBSERVATIONS :**
#
# * **From the correlation graph we clearly observe that the features related to temperature and features related to humidity have positive correlation within themselves whereas have a a very little to no correlation with each other.**
# * **Humidity outside have a strong negative correlation with temperature levels as already discussed.**
# * **Apart from that we observe that a couple features such as humidity at station, temperature outside the building and temperature in the living room have a comparatively high absolute correlation (above 0.12) with Appliances energy consumption.**

# %%
# let us plot the variation of energy consumption with these variables
fig, axes = plt.subplots(4,5,figsize = (50,40))
for i, col in enumerate(cols[:-1]):
  ax = axes[i//5, i%5]
  ax.scatter(energy_df[col], energy_df['Appliances'])
  ax.set_xlabel(col)
  ax.set_ylabel('Appliances')

# %% [markdown]
# **Lets look at the dependence of appliance energy consumption on newly created variables !**

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['month', 'weekday', 'hour', 'Appliances']].corr(), annot=True, ax=ax)

# %% [markdown]
# * **As we have observed earlier as well, there seenms to be no correlation between month and the observed energy use i.e. the enegy consumption pretty much remains similar over all months. Similarly there is no direct effect of weekdays on appliance energy consumption.**
# * **Although there is a correlation of 0.22 between hour and appliances**

# %%
def create_session(x):
  if x <= 6 or x >= 22:
    return 1
  elif x>6 and x <=15:
    return 2
  else:
    return 3

# %%
# lets create a new column based on our observations
energy_df['session'] = energy_df['hour'].apply(lambda x : create_session(x))

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['session', 'Appliances']].corr(), ax = ax, annot=True)

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
sns.boxplot(x='session',y='Appliances',data=energy_df, ax = ax)

# %% [markdown]
# **We were now able to increase the correlation to 0.34 by making creating this new row. We see a clear distinction of power consumtion in different sessions.**

# %% [markdown]
# **Lets look at features related to weather as well.**

# %%
fig,ax = plt.subplots(1,1,figsize=(20,15))
sns.heatmap(energy_df[weather_cols + cols].corr(), ax = ax, annot=True)

# %% [markdown]
# **Tdewpoint shows a high correlation with most of the tempearture and humidity level features than any other weather parameters. Pressure, windspeed and visibiltiy show little to no correlation. We might need to include these only these feaatures in our final model**

# %% [markdown]
# **Lets now deep dive into reducing the temperature and humidity parameters through some feature engineering and come up with features that explain maximum variability.**

# %%
temp_cols = list(set(list(temp_dict.values())) - {'temp_outside', 'temp_station'})
energy_df['mean_temp'] = energy_df[temp_cols].mean(axis=1)
energy_df[['mean_temp', 'Appliances']].corr()
# Out:
#             mean_temp  Appliances
# mean_temp     1.00000     0.05474
# Appliances    0.05474     1.00000

# %% [markdown]
# **Since most of the temperature variables inside the room show little to know correlation with target variable, lets try to find components that could explain maximum variance, which might improve the correlation with target variable as well.**

# %% [markdown]
# **Before doing PCA, I need to split the data into train and test, and fit PCA on train set**

# %% [markdown]
# ### **PCA on temperatures**

# %%
train_energy_df, test_energy_df = train_test_split(energy_df, test_size=0.2, random_state=1)

# %%
pca = PCA()
pca.fit(train_energy_df[temp_cols])
temp_pca = pca.transform(energy_df[temp_cols])
variance = pca.explained_variance_ratio_*100
fig, ax = plt.subplots(1,1,figsize=(7,5))
ax.bar(range(len(variance)), variance)
ax.plot(range(len(variance)), np.cumsum(variance),'r.-',linewidth=2, label='Cummulative variance %')
ax.set_xlabel('Principal components')
ax.set_ylabel('Explained variance %')
plt.legend(loc='best')

# %%
variance
# Out:
# array([84.42749838,  7.33014216,  2.3562388 ,  2.09550508,  1.47195967,
#         1.21891325,  0.69977714,  0.39996553])

# %% [markdown]
# First two components seem to explain more than 91 % of variance in data.

# %%
for i in range(temp_pca.shape[1]):
  energy_df[f'temp_pca{i+1}'] = temp_pca[:,i]

# %%
fig,ax = plt.subplots(1,1,figsize=(9,7))
sns.heatmap(energy_df[['temp_pca1', 'temp_pca2', 'temp_pca3', 'temp_pca4','temp_pca5', 'temp_pca6', 'temp_pca7', 'temp_pca8', 'Appliances']].corr(), ax = ax, annot=True)

# %%
fig, axes = plt.subplots(1,2,figsize=(13,5))
for i, j in enumerate((6,8)):
  axes[i].scatter(energy_df[f'temp_pca{j}'], energy_df['Appliances'])

# %%
#Lets look at components of humid_pca4
dict(zip(temp_cols, pca.components_[7,:]))
# Out:
# {'temp_bath': -0.21732855159144793,
#  'temp_iron': -0.2402654099158844,
#  'temp_kitchen': 0.6252020918393113,
#  'temp_laundry': -0.29689595991058604,
#  'temp_living': -0.11736304703987971,
#  'temp_office': -0.09845473026092912,
#  'temp_parents': 0.6025874320322212,
#  'temp_teen': -0.1715719523850327}

# %% [markdown]
# ### **PCA on humidity**

# %%
humid_cols = list(set(list(humid_dict.values())) - {'humid_outside', 'humid_station'})
energy_df['mean_humid'] = energy_df[temp_cols].mean(axis=1)
energy_df[['mean_humid', 'Appliances']].corr()
# Out:
#             mean_humid  Appliances
# mean_humid     1.00000     0.05474
# Appliances     0.05474     1.00000

# %%
pca = PCA()
pca.fit(train_energy_df[humid_cols])
humid_pca = pca.transform(energy_df[humid_cols])
variance = pca.explained_variance_ratio_*100
fig, ax = plt.subplots(1,1,figsize=(7,5))
ax.bar(range(len(variance)), variance)
ax.plot(range(len(variance)), np.cumsum(variance),'r.-',linewidth=2, label='Cummulative variance %')
ax.set_xlabel('Principal components')
ax.set_ylabel('Explained variance %')
plt.legend(loc='best')

# %%
variance
# Out:
# array([62.09137315, 28.02035975,  3.84761759,  2.19313449,  1.40502588,
#         1.22143306,  0.64956943,  0.57148664])

# %%
for i in range(humid_pca.shape[1]):
  energy_df[f'humid_pca{i+1}'] = humid_pca[:,i]

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['humid_pca1', 'humid_pca2', 'humid_pca3', 'humid_pca4', 'humid_pca6', 'humid_pca7', 'humid_pca8', 'Appliances']].corr(), ax = ax, annot=True)

# %%
plt.scatter(energy_df['humid_pca4'], energy_df['Appliances'])

# %%
#Lets look at components of humid_pca4
dict(zip(humid_cols, pca.components_[3,:]))
# Out:
# {'humid_bath': -0.005052352457213735,
#  'humid_iron': 0.07897694512980195,
#  'humid_kitchen': 0.4123122284268892,
#  'humid_laundry': 0.2908803708815095,
#  'humid_living': -0.539578523176147,
#  'humid_office': 0.4102126219725879,
#  'humid_parents': -0.01890427923705676,
#  'humid_teen': -0.5285334448509861}

# %%
energy_df['diff_temp'] = energy_df['temp_outside'] - energy_df['mean_temp']
energy_df[['diff_temp', 'Appliances']].corr()
# Out:
#             diff_temp  Appliances
# diff_temp     1.00000     0.12411
# Appliances    0.12411     1.00000

# %%
energy_df['log_Appliances'] = np.log(energy_df['Appliances'])
sns.histplot(energy_df.log_Appliances,bins=50)

# %% [markdown]
# # **Modeling with PCA features**

# %%
final_features = ['temp_pca1', 'temp_pca2', 'humid_pca1', 'humid_pca2', 'temp_outside', 'humid_outside', 'weekday', 'session', 'Windspeed', 'Press_mm_hg', 'Appliances']

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[final_features].corr(), ax = ax, annot=True)

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %% [markdown]
# **The ML regressor models that we use are :**
# * **Lasso Regressor**
# * **Ridge Regressor**
# * **KNeighbors Regressor**
# * **Support Vector Regressor**
# * **Random Forest Regressor**
# * **Extra Tree Regressor**
# * **Gradient Boosting Regressor**
# * **XGB Regressor**
# * **MLP Regressor**

# %%
models = [
           ['Lasso: ', Lasso()],
           ['Ridge: ', Ridge()],
           ['KNeighborsRegressor: ',  neighbors.KNeighborsRegressor()],
           ['SVR:' , SVR(kernel='rbf')],
           ['RandomForest ',RandomForestRegressor()],
           ['ExtraTreeRegressor :',ExtraTreesRegressor()],
           ['GradientBoostingRegressor: ', GradientBoostingRegressor()] ,
           ['XGBRegressor: ', xgb.XGBRegressor()] ,
           ['MLPRegressor: ', MLPRegressor(  activation='relu', solver='adam',learning_rate='adaptive',max_iter=1000,learning_rate_init=0.01,alpha=0.01)]
         ]

# %%
model_data = []
for name,curr_model in models :
    curr_model_data = {}
    curr_model.random_state = 78
    curr_model_data["Name"] = name
    start = time.time()
    curr_model.fit(X_train,y_train)
    end = time.time()
    curr_model_data["Train_Time"] = end - start
    curr_model_data["Train_R2_Score"] = r2_score(y_train,curr_model.predict(X_train))
    curr_model_data["Test_R2_Score"] = r2_score(y_test,curr_model.predict(X_test))
    curr_model_data["Test_RMSE_Score"] = np.sqrt(mean_squared_error(y_test,curr_model.predict(X_test)))
    model_data.append(curr_model_data)
# Out:
# [23:25:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
results_df = df = pd.DataFrame(model_data)

# %%
results_df
# Out:
#                           Name  Train_Time  ...  Test_R2_Score  Test_RMSE_Score
# 0                      Lasso:     0.004333  ...      -0.000777         1.028791
# 1                      Ridge:     0.003357  ...       0.124513         0.962240
# 2        KNeighborsRegressor:     0.033362  ...       0.473707         0.746057
# 3                         SVR:   14.644733  ...       0.142789         0.952143
# 4                RandomForest    14.248024  ...       0.559954         0.682193
# 5         ExtraTreeRegressor :    4.075233  ...       0.641419         0.615817
# 6  GradientBoostingRegressor:     4.221167  ...       0.217850         0.909501
# 7               XGBRegressor:     1.131773  ...       0.213623         0.911956
# 8               MLPRegressor:     6.554631  ...       0.260662         0.884260
#
# [9 rows x 5 columns]

# %%
results_df.plot.bar(x="Name", y=['Test_R2_Score' , 'Train_R2_Score' , 'Test_RMSE_Score'], title = 'Results' , width = .6, figsize= (20,8))

# %% [markdown]
# **OBSERVATIONS :**
#
# * **Extra Tree Regressor performs the best so far with a R2 score of 0.59 and RMSE of 0.65.**
# * **Lasso regression is the worst performing model so far.**

# %% [markdown]
# # **Hyper-parameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
reg = ExtraTreesRegressor(random_state=40)
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid, cv = 5, n_jobs = -1 , scoring='r2' , verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(random_state=40), n_jobs=-1,
#              param_grid=[{'max_depth': [80, 150, 200, 250],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'n_estimators': [100, 150, 200, 250]}],
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'sqrt', 'n_estimators': 250}

# %%
grid_search.best_estimator_
# Out:
# ExtraTreesRegressor(max_depth=80, max_features='sqrt', n_estimators=250,
#                     random_state=40)

# %%
grid_search.best_estimator_.score(X_train,y_train)
# Out:
# 1.0

# %%
grid_search.best_estimator_.score(X_test,y_test)
# Out:
# 0.6420092203610108

# %%
np.sqrt(mean_squared_error(y_test, grid_search.best_estimator_.predict(X_test)))
# Out:
# 0.6153103158401956

# %% [markdown]
# **We observe a minute improvement in R2 score and RMSE score after hyper parameter tuning of Extra Trees Regressor.**

# %%
errors = []
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ < 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ < 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ > 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ > 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['Below 300', 'Above 300'], height=errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **The model seems to make more errors in predicting the ones where actual energy consumption levels of appliances is quite high (above 300 Wh). While below 300 Wh, the RMSE is below the average RMS of entire test set.**

# %%
X_test = pd.DataFrame(X_test, columns=final_features[:-1])
y_test = pd.Series(y_test, name = 'Appliances')

# %%
session_errors = []
for i in range(1,4):
  session_errors.append(np.sqrt(mean_squared_error(y_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['10 PM - 6 AM', '6 AM - 3 PM', '3 PM - 10 PM'], height=session_errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **When we look at the root mean squared errors made in prediction of energy consumption in appliances at different time of the day, we observe that errors made are quite less than the average RMSE of entire test set. Which is quite intuitive since we had little to no variance in energy consumption in those hours. However the errors are above average for other two time frames, where we had seen a quite a variance in energy levels.**

# %%
fig, axes = plt.subplots(1,1,figsize=(20,5))
plt.plot(range(len(y_test[:200])), y_test[:200]*sc_y.scale_ + sc_y.mean_, label='actual')
plt.plot(range(len(y_test[:200])), grid_search.best_estimator_.predict(X_test.iloc[:200,:])*sc_y.scale_ + sc_y.mean_, label='predicted')
plt.legend(loc='best')
plt.ylabel('Appliance energy consumption (Wh)')
plt.xlabel('Samples')
# Out:
# Text(0.5, 0, 'Samples')

# %%
feature_indices = np.argsort(grid_search.best_estimator_.feature_importances_)
importances = grid_search.best_estimator_.feature_importances_
indices = np.argsort(importances)[::-1]
names = [final_train_df.columns[i] for i in indices]

plt.figure(figsize=(10,6))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()

# %% [markdown]
# **Looking at the feature importances, it is clear that the PCA features of temperature and humidity hold slightly higher feature importances compared to others. However almost all the features used for modelling hold equal importance**

# %% [markdown]
# # **Modeling Without PCA features**

# %% [markdown]
# **Including all temperature and humidity features and engineered feature 'session' in our features set.**

# %%
final_features = ['temp_laundry','temp_bath', 'temp_kitchen', 'temp_parents', 'temp_office', 'temp_living', 'temp_teen', 'temp_iron','humid_kitchen',
 'humid_office', 'humid_bath', 'humid_living', 'humid_parents', 'humid_laundry', 'humid_teen', 'humid_iron',
  'temp_outside', 'humid_outside', 'temp_station', 'humid_station', 'weekday', 'session', 'Windspeed', 'Press_mm_hg', 'Appliances']

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %%
models = [
           ['Lasso: ', Lasso()],
           ['Ridge: ', Ridge()],
           ['KNeighborsRegressor: ',  neighbors.KNeighborsRegressor()],
           ['SVR:' , SVR(kernel='rbf')],
           ['RandomForest ',RandomForestRegressor()],
           ['ExtraTreeRegressor :',ExtraTreesRegressor()],
           ['GradientBoostingRegressor: ', GradientBoostingRegressor()],
           ['XGBRegressor: ', xgb.XGBRegressor()],
           ['MLPRegressor: ', MLPRegressor(  activation='relu', solver='adam',learning_rate='adaptive',max_iter=1000,learning_rate_init=0.01,alpha=0.01)]
         ]

# %%
model_data = []
for name,curr_model in models :
    curr_model_data = {}
    curr_model.random_state = 78
    curr_model_data["Name"] = name
    start = time.time()
    curr_model.fit(X_train,y_train)
    end = time.time()
    curr_model_data["Train_Time"] = end - start
    curr_model_data["Train_R2_Score"] = r2_score(y_train,curr_model.predict(X_train))
    curr_model_data["Test_R2_Score"] = r2_score(y_test,curr_model.predict(X_test))
    curr_model_data["Test_RMSE_Score"] = np.sqrt(mean_squared_error(y_test,curr_model.predict(X_test)))
    model_data.append(curr_model_data)
# Out:
# [23:39:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
results_df = pd.DataFrame(model_data)

# %%
results_df
# Out:
#                           Name  Train_Time  ...  Test_R2_Score  Test_RMSE_Score
# 0                      Lasso:     0.018935  ...      -0.000777         1.028791
# 1                      Ridge:     0.007070  ...       0.185596         0.928064
# 2        KNeighborsRegressor:     0.001178  ...       0.485171         0.737887
# 3                         SVR:   14.867502  ...       0.242499         0.895055
# 4                RandomForest    35.305279  ...       0.593457         0.655709
# 5         ExtraTreeRegressor :    8.951756  ...       0.644521         0.613148
# 6  GradientBoostingRegressor:     8.193489  ...       0.271252         0.877904
# 7               XGBRegressor:     1.822634  ...       0.271605         0.877691
# 8               MLPRegressor:    11.476985  ...       0.397394         0.798316
#
# [9 rows x 5 columns]

# %%
results_df.plot.bar(x="Name", y=['Test_R2_Score' , 'Train_R2_Score' , 'Test_RMSE_Score'], title = 'Results' , width = .6, figsize= (20,8))

# %% [markdown]
# **The model results are almost similar to that observed in models trained with PCA feature set.**

# %% [markdown]
# # **Hyper-parameter Tuning**

# %%
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
reg = ExtraTreesRegressor(random_state=40)
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid, cv = 5, n_jobs = -1 , scoring='r2' , verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(random_state=40), n_jobs=-1,
#              param_grid=[{'max_depth': [80, 150, 200, 250],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'n_estimators': [100, 150, 200, 250]}],
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
grid_search.best_estimator_
# Out:
# ExtraTreesRegressor(max_depth=80, max_features='sqrt', n_estimators=200,
#                     random_state=40)

# %%
grid_search.best_estimator_.score(X_train,y_train)
# Out:
# 1.0

# %%
grid_search.best_estimator_.score(X_test,y_test)
# Out:
# 0.6453971723995422

# %%
np.sqrt(mean_squared_error(y_test, grid_search.best_estimator_.predict(X_test)))
# Out:
# 0.6123918084485078

# %%
errors = []
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ < 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ < 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ > 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ > 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['Below 300', 'Above 300'], height=errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **The model seems to make more errors in predicting the ones where actual energy consumption levels of appliances is quite high (above 300 Wh). While below 300 Wh, the RMSE is below the average RMS of entire test set.**

# %%
X_test = pd.DataFrame(X_test, columns=final_features[:-1])
y_test = pd.Series(y_test, name = 'Appliances')

# %%
session_errors = []
for i in range(1,4):
  session_errors.append(np.sqrt(mean_squared_error(y_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['10 PM - 6 AM', '6 AM - 3 PM', '3 PM - 10 PM'], height=session_errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Session (Time of the day)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **When we look at the root mean squared errors made in prediction of energy consumption in appliances at different time of the day, we observe that errors made are quite less than the average RMSE of entire test set. Which is quite intuitive since we had little to no variance in energy consumption in those hours. However the errors are above average for other two time frames, where we had seen a quite a variance in energy levels.**

# %%
fig, axes = plt.subplots(1,1,figsize=(20,5))
plt.plot(range(len(y_test[:200])), y_test[:200]*sc_y.scale_ + sc_y.mean_, label='actual',linewidth=2)
plt.plot(range(len(y_test[:200])), grid_search.best_estimator_.predict(X_test.iloc[:200,:])*sc_y.scale_ + sc_y.mean_, label='predicted',linewidth=2)
plt.legend(loc='best')
plt.ylabel('Appliance energy consumption (Wh)')
plt.xlabel('Samples')
# Out:
# Text(0.5, 0, 'Samples')

# %% [markdown]
# **The above figure represents actual and predicted values of 200 samples in test set.**

# %%
feature_indices = np.argsort(grid_search.best_estimator_.feature_importances_)
importances = grid_search.best_estimator_.feature_importances_
indices = np.argsort(importances)[::-1]
names = [final_train_df.columns[i] for i in indices]

plt.figure(figsize=(10,6))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()

# %% [markdown]
# **In the case where we don't include any PCA features, the engineered feature 'session' seems to hold most importance among all the features.**

# %% [markdown]
# # **Neural Networks**

# %%
final_features = ['temp_pca1', 'temp_pca2', 'humid_pca1', 'humid_pca2', 'temp_outside', 'humid_outside', 'session', 'Windspeed', 'Press_mm_hg', 'weekday', 'Appliances']

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %%
def R_squared(y_true, y_pred):
  unexplained_error = tf.reduce_sum(tf.square(y_true - y_pred))
  total_error = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true, axis=0)))
  R2 = 1. - tf.truediv(unexplained_error, total_error)
  return R2

# %%
NN_model = Sequential([
                    Input((None,X_train.shape[1])),
                    layers.Dense(32,activation='relu',kernel_initializer='normal'),
                    layers.Dense(64,activation='relu', kernel_initializer='normal'),
                    layers.Dense(64,activation='relu', kernel_initializer='normal'),
                    layers.Dense(1,kernel_initializer='normal',activation='linear'),
])
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=[R_squared])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, None, 32)          352
#
#  dense_1 (Dense)             (None, None, 64)          2112
#
#  dense_2 (Dense)             (None, None, 64)          4160
#
#  dense_3 (Dense)             (None, None, 1)           65
#
# =================================================================
# Total params: 6,689
# Trainable params: 6,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
NN_model.fit(X_train, y_train, epochs=500, validation_data=(X_test, y_test), workers=-1)
# Out:
# Epoch 1/500
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# 493/494 [============================>.] - ETA: 0s - loss: 0.8775 - R_squared: 0.0601WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# 494/494 [==============================] - 3s 4ms/step - loss: 0.8785 - R_squared: 0.0600 - val_loss: 0.8962 - val_R_squared: 0.1186
# Epoch 2/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.8357 - R_squared: 0.0603 - val_loss: 0.8739 - val_R_squared: 0.1395
# Epoch 3/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.8065 - R_squared: 0.0672 - val_loss: 0.8533 - val_R_squared: 0.1547
# Epoch 4/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.7832 - R_squared: 0.1130 - val_loss: 0.8389 - val_R_squared: 0.1532
# Epoch 5/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.7683 - R_squared: 0.0776 - val_loss: 0.8166 - val_R_squared: 0.1395
# Epoch 6/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.7538 - R_squared: 0.1204 - val_loss: 0.8162 - val_R_squared: 0.1842
# Epoch 7/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.7399 - R_squared: 0.1590 - val_loss: 0.7944 - val_R_squared: 0.1608
# Epoch 8/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7254 - R_squared: 0.1844 - val_loss: 0.7830 - val_R_squared: 0.1602
# Epoch 9/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.7109 - R_squared: 0.1746 - val_loss: 0.7913 - val_R_squared: 0.1448
# Epoch 10/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.7060 - R_squared: 0.1824 - val_loss: 0.7809 - val_R_squared: 0.1367
# Epoch 11/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6963 - R_squared: 0.1841 - val_loss: 0.7721 - val_R_squared: 0.1700
# Epoch 12/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.6909 - R_squared: 0.1883 - val_loss: 0.7590 - val_R_squared: 0.1871
# Epoch 13/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.6856 - R_squared: 0.2022 - val_loss: 0.7579 - val_R_squared: 0.2286
# Epoch 14/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6789 - R_squared: 0.1714 - val_loss: 0.7501 - val_R_squared: 0.1773
# Epoch 15/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.6627 - R_squared: 0.2445 - val_loss: 0.7467 - val_R_squared: 0.2252
# Epoch 16/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6552 - R_squared: 0.2238 - val_loss: 0.7504 - val_R_squared: 0.1990
# Epoch 17/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.6544 - R_squared: 0.2276 - val_loss: 0.7318 - val_R_squared: 0.2414
# Epoch 18/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.6493 - R_squared: 0.2505 - val_loss: 0.7275 - val_R_squared: 0.2188
# Epoch 19/500
# 494/494 [==============================] - 5s 10ms/step - loss: 0.6404 - R_squared: 0.2488 - val_loss: 0.7128 - val_R_squared: 0.2494
# Epoch 20/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6347 - R_squared: 0.2495 - val_loss: 0.7386 - val_R_squared: 0.1427
# Epoch 21/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6322 - R_squared: 0.2414 - val_loss: 0.7326 - val_R_squared: 0.1991
# Epoch 22/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6289 - R_squared: 0.2237 - val_loss: 0.7041 - val_R_squared: 0.2316
# Epoch 23/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6224 - R_squared: 0.2428 - val_loss: 0.7318 - val_R_squared: 0.1617
# Epoch 24/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.6169 - R_squared: 0.2716 - val_loss: 0.6872 - val_R_squared: 0.2516
# Epoch 25/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.6096 - R_squared: 0.2843 - val_loss: 0.7134 - val_R_squared: 0.2056
# Epoch 26/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6108 - R_squared: 0.2583 - val_loss: 0.7198 - val_R_squared: 0.2276
# Epoch 27/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.6047 - R_squared: 0.2915 - val_loss: 0.7243 - val_R_squared: 0.1569
# Epoch 28/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6044 - R_squared: 0.2836 - val_loss: 0.6873 - val_R_squared: 0.2516
# Epoch 29/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5986 - R_squared: 0.2493 - val_loss: 0.7040 - val_R_squared: 0.2500
# Epoch 30/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5925 - R_squared: 0.2746 - val_loss: 0.6959 - val_R_squared: 0.2430
# Epoch 31/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5863 - R_squared: 0.3112 - val_loss: 0.7025 - val_R_squared: 0.2424
# Epoch 32/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5898 - R_squared: 0.2795 - val_loss: 0.6864 - val_R_squared: 0.2674
# Epoch 33/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5880 - R_squared: 0.2802 - val_loss: 0.6784 - val_R_squared: 0.2440
# Epoch 34/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.5776 - R_squared: 0.3118 - val_loss: 0.6877 - val_R_squared: 0.2060
# Epoch 35/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5765 - R_squared: 0.2720 - val_loss: 0.6860 - val_R_squared: 0.2796
# Epoch 36/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5752 - R_squared: 0.2648 - val_loss: 0.6733 - val_R_squared: 0.2775
# Epoch 37/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5757 - R_squared: 0.2548 - val_loss: 0.6903 - val_R_squared: 0.2145
# Epoch 38/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5713 - R_squared: 0.3030 - val_loss: 0.6641 - val_R_squared: 0.2909
# Epoch 39/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.5659 - R_squared: 0.3426 - val_loss: 0.6692 - val_R_squared: 0.2876
# Epoch 40/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5652 - R_squared: 0.2934 - val_loss: 0.6964 - val_R_squared: 0.2649
# Epoch 41/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5690 - R_squared: 0.2762 - val_loss: 0.7413 - val_R_squared: 0.0915
# Epoch 42/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5586 - R_squared: 0.3126 - val_loss: 0.7119 - val_R_squared: 0.1423
# Epoch 43/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5595 - R_squared: 0.3039 - val_loss: 0.6689 - val_R_squared: 0.2524
# Epoch 44/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5572 - R_squared: 0.2828 - val_loss: 0.6742 - val_R_squared: 0.2744
# Epoch 45/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5441 - R_squared: 0.3263 - val_loss: 0.6819 - val_R_squared: 0.2354
# Epoch 46/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5430 - R_squared: 0.3200 - val_loss: 0.6808 - val_R_squared: 0.2080
# Epoch 47/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5465 - R_squared: 0.2909 - val_loss: 0.6747 - val_R_squared: 0.3035
# Epoch 48/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5398 - R_squared: 0.3403 - val_loss: 0.6792 - val_R_squared: 0.2589
# Epoch 49/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5410 - R_squared: 0.3294 - val_loss: 0.6844 - val_R_squared: 0.2863
# Epoch 50/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5428 - R_squared: 0.2897 - val_loss: 0.6619 - val_R_squared: 0.2576
# Epoch 51/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5347 - R_squared: 0.3175 - val_loss: 0.6662 - val_R_squared: 0.2395
# Epoch 52/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5291 - R_squared: 0.3630 - val_loss: 0.6624 - val_R_squared: 0.2963
# Epoch 53/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5279 - R_squared: 0.3540 - val_loss: 0.7136 - val_R_squared: 0.1284
# Epoch 54/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5267 - R_squared: 0.3480 - val_loss: 0.6570 - val_R_squared: 0.2632
# Epoch 55/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5319 - R_squared: 0.2823 - val_loss: 0.6606 - val_R_squared: 0.2932
# Epoch 56/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5243 - R_squared: 0.3673 - val_loss: 0.6743 - val_R_squared: 0.1992
# Epoch 57/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5209 - R_squared: 0.3708 - val_loss: 0.6621 - val_R_squared: 0.2626
# Epoch 58/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5153 - R_squared: 0.3561 - val_loss: 0.6595 - val_R_squared: 0.2588
# Epoch 59/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5161 - R_squared: 0.3339 - val_loss: 0.6442 - val_R_squared: 0.2850
# Epoch 60/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5115 - R_squared: 0.3607 - val_loss: 0.6645 - val_R_squared: 0.2300
# Epoch 61/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.5106 - R_squared: 0.3761 - val_loss: 0.6547 - val_R_squared: 0.2716
# Epoch 62/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5123 - R_squared: 0.3494 - val_loss: 0.6419 - val_R_squared: 0.3167
# Epoch 63/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5082 - R_squared: 0.3283 - val_loss: 0.6316 - val_R_squared: 0.3511
# Epoch 64/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5008 - R_squared: 0.3555 - val_loss: 0.6361 - val_R_squared: 0.3372
# Epoch 65/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5061 - R_squared: 0.3214 - val_loss: 0.6507 - val_R_squared: 0.2212
# Epoch 66/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5034 - R_squared: 0.3588 - val_loss: 0.6427 - val_R_squared: 0.3052
# Epoch 67/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4947 - R_squared: 0.3590 - val_loss: 0.6415 - val_R_squared: 0.3014
# Epoch 68/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4885 - R_squared: 0.3785 - val_loss: 0.6457 - val_R_squared: 0.2878
# Epoch 69/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4953 - R_squared: 0.3881 - val_loss: 0.6328 - val_R_squared: 0.2867
# Epoch 70/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4933 - R_squared: 0.3775 - val_loss: 0.6535 - val_R_squared: 0.2923
# Epoch 71/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4994 - R_squared: 0.3912 - val_loss: 0.6305 - val_R_squared: 0.3251
# Epoch 72/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.4796 - R_squared: 0.4172 - val_loss: 0.6646 - val_R_squared: 0.1663
# Epoch 73/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4828 - R_squared: 0.3462 - val_loss: 0.6618 - val_R_squared: 0.2543
# Epoch 74/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4810 - R_squared: 0.4086 - val_loss: 0.6425 - val_R_squared: 0.2885
# Epoch 75/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4815 - R_squared: 0.3907 - val_loss: 0.6318 - val_R_squared: 0.2710
# Epoch 76/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4806 - R_squared: 0.3679 - val_loss: 0.6481 - val_R_squared: 0.2957
# Epoch 77/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4820 - R_squared: 0.3478 - val_loss: 0.6166 - val_R_squared: 0.3053
# Epoch 78/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4809 - R_squared: 0.4117 - val_loss: 0.6203 - val_R_squared: 0.2860
# Epoch 79/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4760 - R_squared: 0.4245 - val_loss: 0.6365 - val_R_squared: 0.2880
# Epoch 80/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4685 - R_squared: 0.4236 - val_loss: 0.6317 - val_R_squared: 0.2804
# Epoch 81/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4742 - R_squared: 0.3679 - val_loss: 0.6417 - val_R_squared: 0.2773
# Epoch 82/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4705 - R_squared: 0.4060 - val_loss: 0.6204 - val_R_squared: 0.3106
# Epoch 83/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4700 - R_squared: 0.4070 - val_loss: 0.6146 - val_R_squared: 0.3036
# Epoch 84/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4658 - R_squared: 0.4238 - val_loss: 0.6274 - val_R_squared: 0.3233
# Epoch 85/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4654 - R_squared: 0.4205 - val_loss: 0.6242 - val_R_squared: 0.3204
# Epoch 86/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4606 - R_squared: 0.4393 - val_loss: 0.6316 - val_R_squared: 0.2919
# Epoch 87/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4676 - R_squared: 0.3731 - val_loss: 0.6695 - val_R_squared: 0.1794
# Epoch 88/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4606 - R_squared: 0.4017 - val_loss: 0.6226 - val_R_squared: 0.2990
# Epoch 89/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4511 - R_squared: 0.4256 - val_loss: 0.6647 - val_R_squared: 0.2106
# Epoch 90/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4609 - R_squared: 0.4057 - val_loss: 0.6361 - val_R_squared: 0.2795
# Epoch 91/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4584 - R_squared: 0.4289 - val_loss: 0.6457 - val_R_squared: 0.2800
# Epoch 92/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.4485 - R_squared: 0.4398 - val_loss: 0.6274 - val_R_squared: 0.3208
# Epoch 93/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4531 - R_squared: 0.4019 - val_loss: 0.6250 - val_R_squared: 0.2864
# Epoch 94/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4470 - R_squared: 0.4495 - val_loss: 0.6287 - val_R_squared: 0.2811
# Epoch 95/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4503 - R_squared: 0.4065 - val_loss: 0.6026 - val_R_squared: 0.3172
# Epoch 96/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4441 - R_squared: 0.4242 - val_loss: 0.6664 - val_R_squared: 0.1937
# Epoch 97/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4447 - R_squared: 0.4092 - val_loss: 0.6168 - val_R_squared: 0.2738
# Epoch 98/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4499 - R_squared: 0.4473 - val_loss: 0.6020 - val_R_squared: 0.3309
# Epoch 99/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4374 - R_squared: 0.4292 - val_loss: 0.6217 - val_R_squared: 0.3363
# Epoch 100/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4361 - R_squared: 0.4307 - val_loss: 0.6332 - val_R_squared: 0.2673
# Epoch 101/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4420 - R_squared: 0.4161 - val_loss: 0.5982 - val_R_squared: 0.3289
# Epoch 102/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4382 - R_squared: 0.4210 - val_loss: 0.6028 - val_R_squared: 0.3278
# Epoch 103/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4388 - R_squared: 0.4121 - val_loss: 0.5970 - val_R_squared: 0.3370
# Epoch 104/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4289 - R_squared: 0.4469 - val_loss: 0.6303 - val_R_squared: 0.2571
# Epoch 105/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4299 - R_squared: 0.4191 - val_loss: 0.6085 - val_R_squared: 0.3010
# Epoch 106/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4336 - R_squared: 0.4150 - val_loss: 0.6285 - val_R_squared: 0.3192
# Epoch 107/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4253 - R_squared: 0.4804 - val_loss: 0.6401 - val_R_squared: 0.2183
# Epoch 108/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4269 - R_squared: 0.4356 - val_loss: 0.6347 - val_R_squared: 0.2653
# Epoch 109/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4203 - R_squared: 0.4841 - val_loss: 0.6273 - val_R_squared: 0.2781
# Epoch 110/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4342 - R_squared: 0.4232 - val_loss: 0.6191 - val_R_squared: 0.2374
# Epoch 111/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4257 - R_squared: 0.4781 - val_loss: 0.6233 - val_R_squared: 0.2618
# Epoch 112/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.4245 - R_squared: 0.4638 - val_loss: 0.6230 - val_R_squared: 0.3150
# Epoch 113/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4292 - R_squared: 0.4318 - val_loss: 0.5926 - val_R_squared: 0.3602
# Epoch 114/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.4193 - R_squared: 0.4649 - val_loss: 0.6240 - val_R_squared: 0.2773
# Epoch 115/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4217 - R_squared: 0.4506 - val_loss: 0.5975 - val_R_squared: 0.3318
# Epoch 116/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.4199 - R_squared: 0.4609 - val_loss: 0.5910 - val_R_squared: 0.3784
# Epoch 117/500
# 494/494 [==============================] - 2s 5ms/step - loss: 0.4177 - R_squared: 0.4860 - val_loss: 0.6413 - val_R_squared: 0.1970
# Epoch 118/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4139 - R_squared: 0.4591 - val_loss: 0.5842 - val_R_squared: 0.3572
# Epoch 119/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4106 - R_squared: 0.4999 - val_loss: 0.6120 - val_R_squared: 0.2860
# Epoch 120/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4185 - R_squared: 0.4630 - val_loss: 0.5764 - val_R_squared: 0.3737
# Epoch 121/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4130 - R_squared: 0.4216 - val_loss: 0.6182 - val_R_squared: 0.2668
# Epoch 122/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4095 - R_squared: 0.4355 - val_loss: 0.6094 - val_R_squared: 0.3364
# Epoch 123/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4027 - R_squared: 0.4721 - val_loss: 0.6260 - val_R_squared: 0.2976
# Epoch 124/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4208 - R_squared: 0.4557 - val_loss: 0.5844 - val_R_squared: 0.3734
# Epoch 125/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4033 - R_squared: 0.4624 - val_loss: 0.6224 - val_R_squared: 0.2702
# Epoch 126/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4064 - R_squared: 0.4678 - val_loss: 0.6097 - val_R_squared: 0.3387
# Epoch 127/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4092 - R_squared: 0.4751 - val_loss: 0.5996 - val_R_squared: 0.3150
# Epoch 128/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4009 - R_squared: 0.4799 - val_loss: 0.5962 - val_R_squared: 0.3546
# Epoch 129/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3977 - R_squared: 0.4483 - val_loss: 0.6064 - val_R_squared: 0.3132
# Epoch 130/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3964 - R_squared: 0.4520 - val_loss: 0.5827 - val_R_squared: 0.3304
# Epoch 131/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3957 - R_squared: 0.4608 - val_loss: 0.6117 - val_R_squared: 0.3300
# Epoch 132/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4062 - R_squared: 0.4629 - val_loss: 0.5818 - val_R_squared: 0.3332
# Epoch 133/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4079 - R_squared: 0.4756 - val_loss: 0.5688 - val_R_squared: 0.3820
# Epoch 134/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3945 - R_squared: 0.5018 - val_loss: 0.5927 - val_R_squared: 0.3205
# Epoch 135/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3998 - R_squared: 0.4887 - val_loss: 0.5936 - val_R_squared: 0.3331
# Epoch 136/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3993 - R_squared: 0.4660 - val_loss: 0.6021 - val_R_squared: 0.2898
# Epoch 137/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3882 - R_squared: 0.4595 - val_loss: 0.5986 - val_R_squared: 0.2680
# Epoch 138/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3953 - R_squared: 0.5084 - val_loss: 0.6064 - val_R_squared: 0.2735
# Epoch 139/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3901 - R_squared: 0.4821 - val_loss: 0.5786 - val_R_squared: 0.3529
# Epoch 140/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3935 - R_squared: 0.4983 - val_loss: 0.5939 - val_R_squared: 0.3384
# Epoch 141/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3900 - R_squared: 0.4728 - val_loss: 0.5980 - val_R_squared: 0.2928
# Epoch 142/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3907 - R_squared: 0.5014 - val_loss: 0.5973 - val_R_squared: 0.3134
# Epoch 143/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3868 - R_squared: 0.5043 - val_loss: 0.5998 - val_R_squared: 0.3392
# Epoch 144/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3868 - R_squared: 0.4812 - val_loss: 0.5654 - val_R_squared: 0.3616
# Epoch 145/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3855 - R_squared: 0.4884 - val_loss: 0.6090 - val_R_squared: 0.3288
# Epoch 146/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3833 - R_squared: 0.4975 - val_loss: 0.5958 - val_R_squared: 0.3022
# Epoch 147/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3823 - R_squared: 0.5124 - val_loss: 0.5945 - val_R_squared: 0.2974
# Epoch 148/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3801 - R_squared: 0.5029 - val_loss: 0.5948 - val_R_squared: 0.2796
# Epoch 149/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3923 - R_squared: 0.4679 - val_loss: 0.6010 - val_R_squared: 0.2786
# Epoch 150/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3802 - R_squared: 0.4942 - val_loss: 0.5940 - val_R_squared: 0.3178
# Epoch 151/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3726 - R_squared: 0.5240 - val_loss: 0.6247 - val_R_squared: 0.2260
# Epoch 152/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3807 - R_squared: 0.4793 - val_loss: 0.6273 - val_R_squared: 0.2423
# Epoch 153/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3779 - R_squared: 0.5082 - val_loss: 0.6020 - val_R_squared: 0.2928
# Epoch 154/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3828 - R_squared: 0.4841 - val_loss: 0.5840 - val_R_squared: 0.3515
# Epoch 155/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3725 - R_squared: 0.4875 - val_loss: 0.6175 - val_R_squared: 0.2329
# Epoch 156/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3738 - R_squared: 0.5060 - val_loss: 0.5898 - val_R_squared: 0.3114
# Epoch 157/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3758 - R_squared: 0.5020 - val_loss: 0.5924 - val_R_squared: 0.2962
# Epoch 158/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3683 - R_squared: 0.5296 - val_loss: 0.5923 - val_R_squared: 0.3215
# Epoch 159/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3735 - R_squared: 0.5047 - val_loss: 0.5847 - val_R_squared: 0.3537
# Epoch 160/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3742 - R_squared: 0.4874 - val_loss: 0.6003 - val_R_squared: 0.3014
# Epoch 161/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3800 - R_squared: 0.4959 - val_loss: 0.5719 - val_R_squared: 0.3838
# Epoch 162/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3688 - R_squared: 0.5081 - val_loss: 0.5611 - val_R_squared: 0.3778
# Epoch 163/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3724 - R_squared: 0.4976 - val_loss: 0.5983 - val_R_squared: 0.2860
# Epoch 164/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3762 - R_squared: 0.4993 - val_loss: 0.5658 - val_R_squared: 0.3559
# Epoch 165/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3675 - R_squared: 0.5099 - val_loss: 0.6387 - val_R_squared: 0.2005
# Epoch 166/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3649 - R_squared: 0.4882 - val_loss: 0.5707 - val_R_squared: 0.3463
# Epoch 167/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3700 - R_squared: 0.5249 - val_loss: 0.5761 - val_R_squared: 0.3266
# Epoch 168/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3720 - R_squared: 0.5057 - val_loss: 0.5842 - val_R_squared: 0.3680
# Epoch 169/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3663 - R_squared: 0.5275 - val_loss: 0.5949 - val_R_squared: 0.2903
# Epoch 170/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3645 - R_squared: 0.5225 - val_loss: 0.5631 - val_R_squared: 0.3720
# Epoch 171/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3686 - R_squared: 0.5143 - val_loss: 0.5997 - val_R_squared: 0.2882
# Epoch 172/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3660 - R_squared: 0.5032 - val_loss: 0.5713 - val_R_squared: 0.3386
# Epoch 173/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3556 - R_squared: 0.5013 - val_loss: 0.5648 - val_R_squared: 0.3350
# Epoch 174/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3582 - R_squared: 0.4725 - val_loss: 0.5726 - val_R_squared: 0.3555
# Epoch 175/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3596 - R_squared: 0.5535 - val_loss: 0.5682 - val_R_squared: 0.3611
# Epoch 176/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3589 - R_squared: 0.5298 - val_loss: 0.5723 - val_R_squared: 0.3593
# Epoch 177/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3606 - R_squared: 0.5286 - val_loss: 0.5880 - val_R_squared: 0.3295
# Epoch 178/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3565 - R_squared: 0.5117 - val_loss: 0.5671 - val_R_squared: 0.3613
# Epoch 179/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3572 - R_squared: 0.5255 - val_loss: 0.5872 - val_R_squared: 0.3146
# Epoch 180/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3516 - R_squared: 0.5088 - val_loss: 0.5910 - val_R_squared: 0.2919
# Epoch 181/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3550 - R_squared: 0.5112 - val_loss: 0.5659 - val_R_squared: 0.3531
# Epoch 182/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3519 - R_squared: 0.5290 - val_loss: 0.5605 - val_R_squared: 0.3519
# Epoch 183/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3562 - R_squared: 0.5166 - val_loss: 0.5828 - val_R_squared: 0.3542
# Epoch 184/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3535 - R_squared: 0.5452 - val_loss: 0.6048 - val_R_squared: 0.2831
# Epoch 185/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3544 - R_squared: 0.5086 - val_loss: 0.5785 - val_R_squared: 0.3167
# Epoch 186/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3458 - R_squared: 0.5194 - val_loss: 0.5914 - val_R_squared: 0.3268
# Epoch 187/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3540 - R_squared: 0.5432 - val_loss: 0.6271 - val_R_squared: 0.1954
# Epoch 188/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3446 - R_squared: 0.5387 - val_loss: 0.5690 - val_R_squared: 0.3351
# Epoch 189/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3456 - R_squared: 0.5475 - val_loss: 0.6080 - val_R_squared: 0.2951
# Epoch 190/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3509 - R_squared: 0.5311 - val_loss: 0.5694 - val_R_squared: 0.3442
# Epoch 191/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3515 - R_squared: 0.5119 - val_loss: 0.5581 - val_R_squared: 0.3581
# Epoch 192/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3408 - R_squared: 0.5315 - val_loss: 0.5696 - val_R_squared: 0.3466
# Epoch 193/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3447 - R_squared: 0.5300 - val_loss: 0.5844 - val_R_squared: 0.3384
# Epoch 194/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3418 - R_squared: 0.5316 - val_loss: 0.5887 - val_R_squared: 0.3524
# Epoch 195/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3428 - R_squared: 0.5489 - val_loss: 0.5685 - val_R_squared: 0.3463
# Epoch 196/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3447 - R_squared: 0.5231 - val_loss: 0.5620 - val_R_squared: 0.3436
# Epoch 197/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3386 - R_squared: 0.5343 - val_loss: 0.5848 - val_R_squared: 0.3135
# Epoch 198/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3419 - R_squared: 0.5481 - val_loss: 0.5992 - val_R_squared: 0.2884
# Epoch 199/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3504 - R_squared: 0.5424 - val_loss: 0.5817 - val_R_squared: 0.3640
# Epoch 200/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3415 - R_squared: 0.5447 - val_loss: 0.5649 - val_R_squared: 0.3290
# Epoch 201/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3389 - R_squared: 0.5313 - val_loss: 0.5648 - val_R_squared: 0.3276
# Epoch 202/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3384 - R_squared: 0.5206 - val_loss: 0.5779 - val_R_squared: 0.3475
# Epoch 203/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3391 - R_squared: 0.5548 - val_loss: 0.5483 - val_R_squared: 0.3848
# Epoch 204/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3368 - R_squared: 0.5636 - val_loss: 0.6012 - val_R_squared: 0.2561
# Epoch 205/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3458 - R_squared: 0.5419 - val_loss: 0.5792 - val_R_squared: 0.3597
# Epoch 206/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3241 - R_squared: 0.5733 - val_loss: 0.5862 - val_R_squared: 0.3000
# Epoch 207/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3373 - R_squared: 0.5167 - val_loss: 0.5600 - val_R_squared: 0.3752
# Epoch 208/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3393 - R_squared: 0.5667 - val_loss: 0.5627 - val_R_squared: 0.3705
# Epoch 209/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3384 - R_squared: 0.5194 - val_loss: 0.5635 - val_R_squared: 0.3504
# Epoch 210/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3384 - R_squared: 0.5595 - val_loss: 0.5912 - val_R_squared: 0.3071
# Epoch 211/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3355 - R_squared: 0.5549 - val_loss: 0.5719 - val_R_squared: 0.3285
# Epoch 212/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3338 - R_squared: 0.5559 - val_loss: 0.5709 - val_R_squared: 0.3566
# Epoch 213/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3339 - R_squared: 0.5269 - val_loss: 0.5560 - val_R_squared: 0.3577
# Epoch 214/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3370 - R_squared: 0.5502 - val_loss: 0.5808 - val_R_squared: 0.3326
# Epoch 215/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3367 - R_squared: 0.5457 - val_loss: 0.5585 - val_R_squared: 0.3692
# Epoch 216/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3338 - R_squared: 0.5641 - val_loss: 0.5704 - val_R_squared: 0.3514
# Epoch 217/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3246 - R_squared: 0.5641 - val_loss: 0.5608 - val_R_squared: 0.3767
# Epoch 218/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3344 - R_squared: 0.5428 - val_loss: 0.5620 - val_R_squared: 0.3802
# Epoch 219/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3277 - R_squared: 0.5586 - val_loss: 0.5733 - val_R_squared: 0.3362
# Epoch 220/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3264 - R_squared: 0.5843 - val_loss: 0.5599 - val_R_squared: 0.3504
# Epoch 221/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3216 - R_squared: 0.5966 - val_loss: 0.5937 - val_R_squared: 0.2438
# Epoch 222/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3261 - R_squared: 0.5571 - val_loss: 0.6022 - val_R_squared: 0.2560
# Epoch 223/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3270 - R_squared: 0.5481 - val_loss: 0.5865 - val_R_squared: 0.3097
# Epoch 224/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3281 - R_squared: 0.5521 - val_loss: 0.5523 - val_R_squared: 0.3397
# Epoch 225/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3268 - R_squared: 0.5580 - val_loss: 0.5703 - val_R_squared: 0.3359
# Epoch 226/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3243 - R_squared: 0.5292 - val_loss: 0.5652 - val_R_squared: 0.3284
# Epoch 227/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3209 - R_squared: 0.5953 - val_loss: 0.5575 - val_R_squared: 0.3895
# Epoch 228/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3312 - R_squared: 0.5619 - val_loss: 0.5575 - val_R_squared: 0.3696
# Epoch 229/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3209 - R_squared: 0.5692 - val_loss: 0.5572 - val_R_squared: 0.3605
# Epoch 230/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3383 - R_squared: 0.5156 - val_loss: 0.5717 - val_R_squared: 0.3084
# Epoch 231/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3237 - R_squared: 0.5624 - val_loss: 0.5596 - val_R_squared: 0.3652
# Epoch 232/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3222 - R_squared: 0.5562 - val_loss: 0.5616 - val_R_squared: 0.3479
# Epoch 233/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3279 - R_squared: 0.5494 - val_loss: 0.5676 - val_R_squared: 0.3233
# Epoch 234/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3250 - R_squared: 0.5491 - val_loss: 0.5617 - val_R_squared: 0.3480
# Epoch 235/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3210 - R_squared: 0.5728 - val_loss: 0.5635 - val_R_squared: 0.3536
# Epoch 236/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3210 - R_squared: 0.5746 - val_loss: 0.5640 - val_R_squared: 0.3662
# Epoch 237/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3266 - R_squared: 0.5474 - val_loss: 0.6265 - val_R_squared: 0.2394
# Epoch 238/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3180 - R_squared: 0.5673 - val_loss: 0.5490 - val_R_squared: 0.3518
# Epoch 239/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3167 - R_squared: 0.5819 - val_loss: 0.5593 - val_R_squared: 0.3695
# Epoch 240/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3294 - R_squared: 0.5623 - val_loss: 0.5650 - val_R_squared: 0.3680
# Epoch 241/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3156 - R_squared: 0.5563 - val_loss: 0.5571 - val_R_squared: 0.3506
# Epoch 242/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3115 - R_squared: 0.5765 - val_loss: 0.6085 - val_R_squared: 0.2778
# Epoch 243/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3179 - R_squared: 0.5565 - val_loss: 0.5525 - val_R_squared: 0.3520
# Epoch 244/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3158 - R_squared: 0.5551 - val_loss: 0.5476 - val_R_squared: 0.3898
# Epoch 245/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3182 - R_squared: 0.5515 - val_loss: 0.5691 - val_R_squared: 0.3086
# Epoch 246/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3138 - R_squared: 0.5797 - val_loss: 0.5554 - val_R_squared: 0.3537
# Epoch 247/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3173 - R_squared: 0.5566 - val_loss: 0.5580 - val_R_squared: 0.3594
# Epoch 248/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3141 - R_squared: 0.5575 - val_loss: 0.5831 - val_R_squared: 0.3404
# Epoch 249/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3219 - R_squared: 0.5671 - val_loss: 0.5608 - val_R_squared: 0.3434
# Epoch 250/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3160 - R_squared: 0.5872 - val_loss: 0.5493 - val_R_squared: 0.3637
# Epoch 251/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3121 - R_squared: 0.5781 - val_loss: 0.5573 - val_R_squared: 0.3407
# Epoch 252/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3196 - R_squared: 0.5684 - val_loss: 0.5638 - val_R_squared: 0.3376
# Epoch 253/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3113 - R_squared: 0.5941 - val_loss: 0.5966 - val_R_squared: 0.2987
# Epoch 254/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3213 - R_squared: 0.5595 - val_loss: 0.5707 - val_R_squared: 0.3507
# Epoch 255/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3126 - R_squared: 0.5887 - val_loss: 0.5496 - val_R_squared: 0.3917
# Epoch 256/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3159 - R_squared: 0.5762 - val_loss: 0.5584 - val_R_squared: 0.3611
# Epoch 257/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3129 - R_squared: 0.5728 - val_loss: 0.5376 - val_R_squared: 0.3935
# Epoch 258/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3060 - R_squared: 0.5613 - val_loss: 0.5672 - val_R_squared: 0.3269
# Epoch 259/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3092 - R_squared: 0.5738 - val_loss: 0.5759 - val_R_squared: 0.3009
# Epoch 260/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3088 - R_squared: 0.5637 - val_loss: 0.5689 - val_R_squared: 0.3442
# Epoch 261/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3089 - R_squared: 0.5898 - val_loss: 0.5573 - val_R_squared: 0.3685
# Epoch 262/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3056 - R_squared: 0.5831 - val_loss: 0.5626 - val_R_squared: 0.3359
# Epoch 263/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3018 - R_squared: 0.5817 - val_loss: 0.5738 - val_R_squared: 0.3096
# Epoch 264/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3124 - R_squared: 0.5848 - val_loss: 0.5596 - val_R_squared: 0.3649
# Epoch 265/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3169 - R_squared: 0.5571 - val_loss: 0.5480 - val_R_squared: 0.3707
# Epoch 266/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3037 - R_squared: 0.5782 - val_loss: 0.5602 - val_R_squared: 0.3564
# Epoch 267/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2985 - R_squared: 0.5815 - val_loss: 0.6068 - val_R_squared: 0.2187
# Epoch 268/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3090 - R_squared: 0.5818 - val_loss: 0.5549 - val_R_squared: 0.3301
# Epoch 269/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3065 - R_squared: 0.5678 - val_loss: 0.5702 - val_R_squared: 0.3450
# Epoch 270/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3059 - R_squared: 0.5652 - val_loss: 0.5627 - val_R_squared: 0.3146
# Epoch 271/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3044 - R_squared: 0.5754 - val_loss: 0.5499 - val_R_squared: 0.3465
# Epoch 272/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3045 - R_squared: 0.5968 - val_loss: 0.5328 - val_R_squared: 0.4017
# Epoch 273/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3047 - R_squared: 0.5550 - val_loss: 0.5501 - val_R_squared: 0.3683
# Epoch 274/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3102 - R_squared: 0.5797 - val_loss: 0.5469 - val_R_squared: 0.3504
# Epoch 275/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2979 - R_squared: 0.5960 - val_loss: 0.5992 - val_R_squared: 0.2759
# Epoch 276/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3091 - R_squared: 0.5800 - val_loss: 0.5572 - val_R_squared: 0.3231
# Epoch 277/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3008 - R_squared: 0.5881 - val_loss: 0.5672 - val_R_squared: 0.3401
# Epoch 278/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2921 - R_squared: 0.6100 - val_loss: 0.5713 - val_R_squared: 0.3370
# Epoch 279/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3050 - R_squared: 0.5746 - val_loss: 0.5651 - val_R_squared: 0.3594
# Epoch 280/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3011 - R_squared: 0.5807 - val_loss: 0.5609 - val_R_squared: 0.3703
# Epoch 281/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2957 - R_squared: 0.5912 - val_loss: 0.5474 - val_R_squared: 0.3873
# Epoch 282/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3161 - R_squared: 0.5675 - val_loss: 0.5589 - val_R_squared: 0.3933
# Epoch 283/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2962 - R_squared: 0.5951 - val_loss: 0.5574 - val_R_squared: 0.3385
# Epoch 284/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.3054 - R_squared: 0.5792 - val_loss: 0.5481 - val_R_squared: 0.3714
# Epoch 285/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2884 - R_squared: 0.5925 - val_loss: 0.5404 - val_R_squared: 0.3938
# Epoch 286/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3026 - R_squared: 0.5853 - val_loss: 0.5590 - val_R_squared: 0.3687
# Epoch 287/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2983 - R_squared: 0.5825 - val_loss: 0.5612 - val_R_squared: 0.3849
# Epoch 288/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3016 - R_squared: 0.5868 - val_loss: 0.5414 - val_R_squared: 0.3890
# Epoch 289/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2904 - R_squared: 0.5789 - val_loss: 0.5854 - val_R_squared: 0.2886
# Epoch 290/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2947 - R_squared: 0.5997 - val_loss: 0.5719 - val_R_squared: 0.3378
# Epoch 291/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2964 - R_squared: 0.5922 - val_loss: 0.5444 - val_R_squared: 0.3718
# Epoch 292/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2988 - R_squared: 0.5726 - val_loss: 0.5555 - val_R_squared: 0.3621
# Epoch 293/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3026 - R_squared: 0.5807 - val_loss: 0.5762 - val_R_squared: 0.3266
# Epoch 294/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2985 - R_squared: 0.5444 - val_loss: 0.6101 - val_R_squared: 0.2734
# Epoch 295/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3005 - R_squared: 0.5835 - val_loss: 0.5803 - val_R_squared: 0.2995
# Epoch 296/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3024 - R_squared: 0.5933 - val_loss: 0.5861 - val_R_squared: 0.3115
# Epoch 297/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2972 - R_squared: 0.5823 - val_loss: 0.5389 - val_R_squared: 0.3745
# Epoch 298/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2891 - R_squared: 0.6016 - val_loss: 0.5375 - val_R_squared: 0.4006
# Epoch 299/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2990 - R_squared: 0.5914 - val_loss: 0.5815 - val_R_squared: 0.3335
# Epoch 300/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2977 - R_squared: 0.5889 - val_loss: 0.5507 - val_R_squared: 0.3622
# Epoch 301/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2890 - R_squared: 0.5962 - val_loss: 0.5766 - val_R_squared: 0.3041
# Epoch 302/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2929 - R_squared: 0.5946 - val_loss: 0.5728 - val_R_squared: 0.3316
# Epoch 303/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2956 - R_squared: 0.6055 - val_loss: 0.5416 - val_R_squared: 0.3689
# Epoch 304/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2942 - R_squared: 0.5483 - val_loss: 0.5638 - val_R_squared: 0.3736
# Epoch 305/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2936 - R_squared: 0.5917 - val_loss: 0.5660 - val_R_squared: 0.3626
# Epoch 306/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2912 - R_squared: 0.6141 - val_loss: 0.5615 - val_R_squared: 0.3404
# Epoch 307/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2873 - R_squared: 0.5838 - val_loss: 0.5614 - val_R_squared: 0.3349
# Epoch 308/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2979 - R_squared: 0.5826 - val_loss: 0.5235 - val_R_squared: 0.3940
# Epoch 309/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2910 - R_squared: 0.5612 - val_loss: 0.5785 - val_R_squared: 0.3448
# Epoch 310/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2956 - R_squared: 0.5608 - val_loss: 0.5490 - val_R_squared: 0.3642
# Epoch 311/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2910 - R_squared: 0.6171 - val_loss: 0.5504 - val_R_squared: 0.3712
# Epoch 312/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2956 - R_squared: 0.6116 - val_loss: 0.5529 - val_R_squared: 0.3659
# Epoch 313/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2904 - R_squared: 0.5933 - val_loss: 0.5561 - val_R_squared: 0.3677
# Epoch 314/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2905 - R_squared: 0.5905 - val_loss: 0.5546 - val_R_squared: 0.3296
# Epoch 315/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2859 - R_squared: 0.6129 - val_loss: 0.5478 - val_R_squared: 0.3638
# Epoch 316/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2815 - R_squared: 0.6096 - val_loss: 0.5433 - val_R_squared: 0.3772
# Epoch 317/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2869 - R_squared: 0.5895 - val_loss: 0.5684 - val_R_squared: 0.3379
# Epoch 318/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2898 - R_squared: 0.6088 - val_loss: 0.5665 - val_R_squared: 0.3386
# Epoch 319/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2851 - R_squared: 0.6278 - val_loss: 0.5619 - val_R_squared: 0.3421
# Epoch 320/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2795 - R_squared: 0.6210 - val_loss: 0.5757 - val_R_squared: 0.3208
# Epoch 321/500
# ...
# Epoch 393/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2684 - R_squared: 0.6316 - val_loss: 0.5642 - val_R_squared: 0.3602
# Epoch 394/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2788 - R_squared: 0.6079 - val_loss: 0.5440 - val_R_squared: 0.3845
# Epoch 395/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2605 - R_squared: 0.6330 - val_loss: 0.5321 - val_R_squared: 0.3816
# Epoch 396/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2737 - R_squared: 0.6049 - val_loss: 0.5368 - val_R_squared: 0.3633
# Epoch 397/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2666 - R_squared: 0.6222 - val_loss: 0.5284 - val_R_squared: 0.3902
# Epoch 398/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2623 - R_squared: 0.6241 - val_loss: 0.5316 - val_R_squared: 0.3611
# Epoch 399/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2696 - R_squared: 0.6109 - val_loss: 0.5318 - val_R_squared: 0.3734
# Epoch 400/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2774 - R_squared: 0.6051 - val_loss: 0.5404 - val_R_squared: 0.3850
# Epoch 401/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2670 - R_squared: 0.6280 - val_loss: 0.5548 - val_R_squared: 0.3562
# Epoch 402/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2658 - R_squared: 0.6214 - val_loss: 0.5633 - val_R_squared: 0.3300
# Epoch 403/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2653 - R_squared: 0.6493 - val_loss: 0.5440 - val_R_squared: 0.3618
# Epoch 404/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2584 - R_squared: 0.6501 - val_loss: 0.5393 - val_R_squared: 0.3758
# Epoch 405/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2624 - R_squared: 0.6428 - val_loss: 0.5418 - val_R_squared: 0.3362
# Epoch 406/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2617 - R_squared: 0.6263 - val_loss: 0.5569 - val_R_squared: 0.3451
# Epoch 407/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2652 - R_squared: 0.6377 - val_loss: 0.5406 - val_R_squared: 0.3400
# Epoch 408/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2619 - R_squared: 0.6206 - val_loss: 0.5452 - val_R_squared: 0.3700
# Epoch 409/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2790 - R_squared: 0.6007 - val_loss: 0.5408 - val_R_squared: 0.3743
# Epoch 410/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2639 - R_squared: 0.6197 - val_loss: 0.5426 - val_R_squared: 0.3729
# Epoch 411/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2599 - R_squared: 0.6124 - val_loss: 0.5674 - val_R_squared: 0.2645
# Epoch 412/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2622 - R_squared: 0.6314 - val_loss: 0.5595 - val_R_squared: 0.3444
# Epoch 413/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2589 - R_squared: 0.6416 - val_loss: 0.5576 - val_R_squared: 0.3212
# Epoch 414/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2736 - R_squared: 0.6296 - val_loss: 0.5403 - val_R_squared: 0.3729
# Epoch 415/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2577 - R_squared: 0.6270 - val_loss: 0.5424 - val_R_squared: 0.3609
# Epoch 416/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2656 - R_squared: 0.6367 - val_loss: 0.5379 - val_R_squared: 0.3570
# Epoch 417/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2588 - R_squared: 0.6343 - val_loss: 0.5628 - val_R_squared: 0.3259
# Epoch 418/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2637 - R_squared: 0.6311 - val_loss: 0.5301 - val_R_squared: 0.3886
# Epoch 419/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2619 - R_squared: 0.6534 - val_loss: 0.5682 - val_R_squared: 0.3336
# Epoch 420/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2655 - R_squared: 0.6280 - val_loss: 0.5339 - val_R_squared: 0.3608
# Epoch 421/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2571 - R_squared: 0.6315 - val_loss: 0.5430 - val_R_squared: 0.3573
# Epoch 422/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2596 - R_squared: 0.6539 - val_loss: 0.5791 - val_R_squared: 0.2958
# Epoch 423/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2619 - R_squared: 0.6224 - val_loss: 0.5350 - val_R_squared: 0.3591
# Epoch 424/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2570 - R_squared: 0.6297 - val_loss: 0.5328 - val_R_squared: 0.3474
# Epoch 425/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2640 - R_squared: 0.6353 - val_loss: 0.5455 - val_R_squared: 0.3644
# Epoch 426/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2627 - R_squared: 0.6311 - val_loss: 0.5309 - val_R_squared: 0.3846
# Epoch 427/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2580 - R_squared: 0.6377 - val_loss: 0.5414 - val_R_squared: 0.3294
# Epoch 428/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2611 - R_squared: 0.6414 - val_loss: 0.5284 - val_R_squared: 0.3808
# Epoch 429/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2572 - R_squared: 0.6466 - val_loss: 0.5268 - val_R_squared: 0.3699
# Epoch 430/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2595 - R_squared: 0.6273 - val_loss: 0.5407 - val_R_squared: 0.3862
# Epoch 431/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2663 - R_squared: 0.6244 - val_loss: 0.5349 - val_R_squared: 0.3575
# Epoch 432/500
# 494/494 [==============================] - 3s 5ms/step - loss: 0.2520 - R_squared: 0.6526 - val_loss: 0.5472 - val_R_squared: 0.3490
# Epoch 433/500
# 494/494 [==============================] - 2s 5ms/step - loss: 0.2547 - R_squared: 0.6536 - val_loss: 0.5387 - val_R_squared: 0.3503
# Epoch 434/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2604 - R_squared: 0.6503 - val_loss: 0.5460 - val_R_squared: 0.3610
# Epoch 435/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2559 - R_squared: 0.6309 - val_loss: 0.5611 - val_R_squared: 0.2986
# Epoch 436/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2574 - R_squared: 0.6498 - val_loss: 0.5330 - val_R_squared: 0.3155
# Epoch 437/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2599 - R_squared: 0.6180 - val_loss: 0.5650 - val_R_squared: 0.3227
# Epoch 438/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2648 - R_squared: 0.6146 - val_loss: 0.5274 - val_R_squared: 0.3669
# Epoch 439/500
# 494/494 [==============================] - 2s 4ms/step - loss: 0.2525 - R_squared: 0.6576 - val_loss: 0.5521 - val_R_squared: 0.3661
# Epoch 440/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2514 - R_squared: 0.6561 - val_loss: 0.5472 - val_R_squared: 0.3539
# Epoch 441/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2591 - R_squared: 0.6576 - val_loss: 0.5486 - val_R_squared: 0.3758
# Epoch 442/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2571 - R_squared: 0.6202 - val_loss: 0.5342 - val_R_squared: 0.3899
# Epoch 443/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2614 - R_squared: 0.6266 - val_loss: 0.5376 - val_R_squared: 0.3630
# Epoch 444/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2546 - R_squared: 0.6468 - val_loss: 0.5300 - val_R_squared: 0.3681
# Epoch 445/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2520 - R_squared: 0.6335 - val_loss: 0.5254 - val_R_squared: 0.3901
# Epoch 446/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2640 - R_squared: 0.6508 - val_loss: 0.5454 - val_R_squared: 0.3692
# Epoch 447/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2547 - R_squared: 0.6419 - val_loss: 0.5257 - val_R_squared: 0.3814
# Epoch 448/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2539 - R_squared: 0.6516 - val_loss: 0.5681 - val_R_squared: 0.2983
# Epoch 449/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2602 - R_squared: 0.6202 - val_loss: 0.5419 - val_R_squared: 0.3562
# Epoch 450/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2521 - R_squared: 0.6525 - val_loss: 0.5475 - val_R_squared: 0.3667
# Epoch 451/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2553 - R_squared: 0.6542 - val_loss: 0.5364 - val_R_squared: 0.3762
# Epoch 452/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2533 - R_squared: 0.6448 - val_loss: 0.5658 - val_R_squared: 0.3310
# Epoch 453/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2626 - R_squared: 0.6294 - val_loss: 0.5555 - val_R_squared: 0.3345
# Epoch 454/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2523 - R_squared: 0.6321 - val_loss: 0.5472 - val_R_squared: 0.3086
# Epoch 455/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2526 - R_squared: 0.6530 - val_loss: 0.5232 - val_R_squared: 0.3968
# Epoch 456/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2543 - R_squared: 0.6501 - val_loss: 0.5436 - val_R_squared: 0.3167
# Epoch 457/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2531 - R_squared: 0.6435 - val_loss: 0.5464 - val_R_squared: 0.4094
# Epoch 458/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2449 - R_squared: 0.6371 - val_loss: 0.5502 - val_R_squared: 0.3518
# Epoch 459/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2523 - R_squared: 0.6522 - val_loss: 0.5644 - val_R_squared: 0.3336
# Epoch 460/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2533 - R_squared: 0.6348 - val_loss: 0.5920 - val_R_squared: 0.2894
# Epoch 461/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2481 - R_squared: 0.6556 - val_loss: 0.5393 - val_R_squared: 0.3454
# Epoch 462/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2532 - R_squared: 0.6327 - val_loss: 0.5272 - val_R_squared: 0.3803
# Epoch 463/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2485 - R_squared: 0.6473 - val_loss: 0.5727 - val_R_squared: 0.3057
# Epoch 464/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2528 - R_squared: 0.6429 - val_loss: 0.5313 - val_R_squared: 0.3737
# Epoch 465/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2547 - R_squared: 0.6491 - val_loss: 0.5552 - val_R_squared: 0.3440
# Epoch 466/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2491 - R_squared: 0.6503 - val_loss: 0.5447 - val_R_squared: 0.3359
# Epoch 467/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2489 - R_squared: 0.6566 - val_loss: 0.5600 - val_R_squared: 0.3570
# Epoch 468/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2539 - R_squared: 0.6446 - val_loss: 0.5519 - val_R_squared: 0.3708
# Epoch 469/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2528 - R_squared: 0.6337 - val_loss: 0.5425 - val_R_squared: 0.3734
# Epoch 470/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2484 - R_squared: 0.6318 - val_loss: 0.5651 - val_R_squared: 0.3350
# Epoch 471/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2462 - R_squared: 0.6611 - val_loss: 0.5471 - val_R_squared: 0.3322
# Epoch 472/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2476 - R_squared: 0.6342 - val_loss: 0.5541 - val_R_squared: 0.3200
# Epoch 473/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2595 - R_squared: 0.6134 - val_loss: 0.5600 - val_R_squared: 0.3466
# Epoch 474/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2552 - R_squared: 0.6077 - val_loss: 0.5228 - val_R_squared: 0.3770
# Epoch 475/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2523 - R_squared: 0.6329 - val_loss: 0.5165 - val_R_squared: 0.3949
# Epoch 476/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2424 - R_squared: 0.6775 - val_loss: 0.5372 - val_R_squared: 0.3385
# Epoch 477/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2446 - R_squared: 0.6442 - val_loss: 0.5271 - val_R_squared: 0.3643
# Epoch 478/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2482 - R_squared: 0.6488 - val_loss: 0.5765 - val_R_squared: 0.3148
# Epoch 479/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2468 - R_squared: 0.6117 - val_loss: 0.5482 - val_R_squared: 0.3527
# Epoch 480/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2461 - R_squared: 0.6568 - val_loss: 0.5203 - val_R_squared: 0.3659
# Epoch 481/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2442 - R_squared: 0.6265 - val_loss: 0.5420 - val_R_squared: 0.3327
# Epoch 482/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2536 - R_squared: 0.6444 - val_loss: 0.5258 - val_R_squared: 0.3660
# Epoch 483/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2467 - R_squared: 0.6311 - val_loss: 0.5369 - val_R_squared: 0.3683
# Epoch 484/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2524 - R_squared: 0.6308 - val_loss: 0.5252 - val_R_squared: 0.3741
# Epoch 485/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2499 - R_squared: 0.6627 - val_loss: 0.5493 - val_R_squared: 0.3280
# Epoch 486/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2476 - R_squared: 0.6520 - val_loss: 0.5474 - val_R_squared: 0.3442
# Epoch 487/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2483 - R_squared: 0.6520 - val_loss: 0.5597 - val_R_squared: 0.3203
# Epoch 488/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2531 - R_squared: 0.6560 - val_loss: 0.5334 - val_R_squared: 0.3344
# Epoch 489/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2463 - R_squared: 0.6374 - val_loss: 0.5521 - val_R_squared: 0.3397
# Epoch 490/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2421 - R_squared: 0.6480 - val_loss: 0.5234 - val_R_squared: 0.3330
# Epoch 491/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2518 - R_squared: 0.6364 - val_loss: 0.5304 - val_R_squared: 0.3757
# Epoch 492/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2448 - R_squared: 0.6465 - val_loss: 0.5185 - val_R_squared: 0.3913
# Epoch 493/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2447 - R_squared: 0.6671 - val_loss: 0.5334 - val_R_squared: 0.3670
# Epoch 494/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2431 - R_squared: 0.6550 - val_loss: 0.5540 - val_R_squared: 0.3332
# Epoch 495/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2420 - R_squared: 0.6250 - val_loss: 0.5656 - val_R_squared: 0.3118
# Epoch 496/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2399 - R_squared: 0.6717 - val_loss: 0.5431 - val_R_squared: 0.3260
# Epoch 497/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2461 - R_squared: 0.6627 - val_loss: 0.5159 - val_R_squared: 0.3905
# Epoch 498/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2501 - R_squared: 0.6528 - val_loss: 0.5174 - val_R_squared: 0.3818
# Epoch 499/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2436 - R_squared: 0.6560 - val_loss: 0.5298 - val_R_squared: 0.3947
# Epoch 500/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2465 - R_squared: 0.6632 - val_loss: 0.5366 - val_R_squared: 0.3611

# %%
hist = NN_model.history

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'R_squared', 'val_loss', 'val_R_squared'])

# %%
plt.plot(range(len(hist.history['R_squared'])), hist.history['R_squared'], label = 'training')
plt.plot(range(len(hist.history['val_R_squared'])), hist.history['val_R_squared'], label = 'validation')
plt.legend(loc='best')
plt.xlabel('Epochs')
plt.ylabel('R2 score')
# Out:
# Text(0, 0.5, 'R2 score')

# %% [markdown]
# **The neural networks although improves the training R2 score over epochs, fails to improve the R2 score on test data.**

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# 1. **The temperature/ humidity features showed little to no pearson correlation w.r.t target variable (<1%), although being highly correlated within themselves.**
#
# 2. **The time zone of the day plays an important role in deciding power consumption of appliances.**
#
# 3. **The best Algorithm to use for this dataset is Extra Trees Regressor (tree based algorithm)**
#
# 4. **PCA helped us to reduce our feature set dimension considerably without affecting performance of our models significantly.**
#
# 5. **The untuned model was able to explain 64.5% of variance (R2 score = 0.645) on test set, while the tuned model was able to explain 64.9% of variance (R2 score = 0.649) on test set which is a tiny improvement of < 1 %**
#
# 6. **The least RMSE score on test data set is found to be around 0.6 by Extra trees regressor model, which is considerably good compared to other models.**
#
# 7. **Tree based models are by far the best model while dealing with data set that has most of its features having no linear correlation with target variable. For similar reasons, linear models such as linear regression, Ridge and Lasso perform the worst.**
